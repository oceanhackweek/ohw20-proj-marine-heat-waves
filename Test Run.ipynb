# %%
# MHW Test Run
import numpy as np
import pandas as pd
import xarray as xr

# %%
# load file - or get data
sda = xr.open_dataset('./sst_example.nc')
sda
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 6443)
# Coordinates:
#     lat           float32 ...
#     lon           float32 ...
#   * time          (time) datetime64[ns] 2002-06-01T09:00:00 ... 2020-01-20T09...
# Data variables:
#     analysed_sst  (time) float32 ...

# %%
# if one point

# %%
sda.analysed_sst.plot()
